# %%
import os

def count_folders_images(directory):
    total_folders = 0
    total_images = 0
    folder_details = {}
    
    for root, dirs, files in os.walk(directory):
        num_folders = len(dirs)
        num_images = len([f for f in files if f.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif'))])
        
        folder_details[root] = {'subfolders': num_folders, 'images': num_images}
        total_folders += num_folders
        total_images += num_images
    
    return total_folders, total_images, folder_details

# Example usage
directory = r"E:\MAJOR PROJECT\Dataset\Indian Sign Language"  # Change this to your target folder
folders, images, details = count_folders_images(directory)
print(f"Total Folders: {folders}")
print(f"Total Images: {images}")
print("Details:")
for folder, info in details.items():
    print(f"{folder}: {info}")
# Out:
# Total Folders: 36
# Total Images: 1564
# Details:
# E:\MAJOR PROJECT\Dataset\Indian Sign Language: {'subfolders': 35, 'images': 0}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\0: {'subfolders': 0, 'images': 46}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\1: {'subfolders': 0, 'images': 49}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\2: {'subfolders': 0, 'images': 44}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\3: {'subfolders': 0, 'images': 42}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\4: {'subfolders': 0, 'images': 44}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\5: {'subfolders': 0, 'images': 43}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\6: {'subfolders': 0, 'images': 41}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\7: {'subfolders': 0, 'images': 46}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\8: {'subfolders': 0, 'images': 42}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\9: {'subfolders': 0, 'images': 36}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\A: {'subfolders': 0, 'images': 54}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\B: {'subfolders': 0, 'images': 50}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\C: {'subfolders': 0, 'images': 47}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\D: {'subfolders': 0, 'images': 44}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\E: {'subfolders': 0, 'images': 45}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\F: {'subfolders': 0, 'images': 48}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\G: {'subfolders': 0, 'images': 46}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\H: {'subfolders': 0, 'images': 4}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\I: {'subfolders': 0, 'images': 48}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\K: {'subfolders': 0, 'images': 45}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\L: {'subfolders': 0, 'images': 48}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\M: {'subfolders': 0, 'images': 45}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\N: {'subfolders': 0, 'images': 46}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\O: {'subfolders': 0, 'images': 47}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\P: {'subfolders': 0, 'images': 47}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\Q: {'subfolders': 0, 'images': 49}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\R: {'subfolders': 0, 'images': 45}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\S: {'subfolders': 0, 'images': 45}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\T: {'subfolders': 1, 'images': 45}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\T\T: {'subfolders': 0, 'images': 4}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\U: {'subfolders': 0, 'images': 50}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\V: {'subfolders': 0, 'images': 42}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\W: {'subfolders': 0, 'images': 46}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\X: {'subfolders': 0, 'images': 48}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\Y: {'subfolders': 0, 'images': 46}
# E:\MAJOR PROJECT\Dataset\Indian Sign Language\Z: {'subfolders': 0, 'images': 47}

# %%
import os

def count_folders_images(directory):
    total_folders = 0
    total_images = 0
    folder_details = {}
    
    for root, dirs, files in os.walk(directory):
        num_folders = len(dirs)
        num_images = len([f for f in files if f.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif'))])
        
        folder_details[root] = {'subfolders': num_folders, 'images': num_images}
        total_folders += num_folders
        total_images += num_images
    
    return total_folders, total_images, folder_details

# Example usage
directory = r"E:\MAJOR PROJECT\Dataset\A"  # Change this to your target folder
folders, images, details = count_folders_images(directory)
print(f"Total Folders: {folders}")
print(f"Total Images: {images}")
print("Details:")
for folder, info in details.items():
    print(f"{folder}: {info}")
# Out:
# Total Folders: 24
# Total Images: 24567
# Details:
# E:\MAJOR PROJECT\Dataset\A: {'subfolders': 24, 'images': 0}
# E:\MAJOR PROJECT\Dataset\A\a: {'subfolders': 0, 'images': 1055}
# E:\MAJOR PROJECT\Dataset\A\b: {'subfolders': 0, 'images': 1031}
# E:\MAJOR PROJECT\Dataset\A\c: {'subfolders': 0, 'images': 1113}
# E:\MAJOR PROJECT\Dataset\A\d: {'subfolders': 0, 'images': 1071}
# E:\MAJOR PROJECT\Dataset\A\e: {'subfolders': 0, 'images': 1047}
# E:\MAJOR PROJECT\Dataset\A\f: {'subfolders': 0, 'images': 1037}
# E:\MAJOR PROJECT\Dataset\A\g: {'subfolders': 0, 'images': 1055}
# E:\MAJOR PROJECT\Dataset\A\h: {'subfolders': 0, 'images': 1045}
# E:\MAJOR PROJECT\Dataset\A\i: {'subfolders': 0, 'images': 478}
# E:\MAJOR PROJECT\Dataset\A\k: {'subfolders': 0, 'images': 1035}
# E:\MAJOR PROJECT\Dataset\A\l: {'subfolders': 0, 'images': 1031}
# E:\MAJOR PROJECT\Dataset\A\m: {'subfolders': 0, 'images': 1053}
# E:\MAJOR PROJECT\Dataset\A\n: {'subfolders': 0, 'images': 1059}
# E:\MAJOR PROJECT\Dataset\A\o: {'subfolders': 0, 'images': 1023}
# E:\MAJOR PROJECT\Dataset\A\p: {'subfolders': 0, 'images': 1143}
# E:\MAJOR PROJECT\Dataset\A\q: {'subfolders': 0, 'images': 1031}
# E:\MAJOR PROJECT\Dataset\A\r: {'subfolders': 0, 'images': 1055}
# E:\MAJOR PROJECT\Dataset\A\s: {'subfolders': 0, 'images': 941}
# E:\MAJOR PROJECT\Dataset\A\t: {'subfolders': 0, 'images': 1047}
# E:\MAJOR PROJECT\Dataset\A\u: {'subfolders': 0, 'images': 1047}
# E:\MAJOR PROJECT\Dataset\A\v: {'subfolders': 0, 'images': 1013}
# E:\MAJOR PROJECT\Dataset\A\w: {'subfolders': 0, 'images': 1049}
# E:\MAJOR PROJECT\Dataset\A\x: {'subfolders': 0, 'images': 1043}
# E:\MAJOR PROJECT\Dataset\A\y: {'subfolders': 0, 'images': 1065}

# %%
import os

def count_folders_images(directory):
    total_folders = 0
    total_images = 0
    folder_details = {}
    
    for root, dirs, files in os.walk(directory):
        num_folders = len(dirs)
        num_images = len([f for f in files if f.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif'))])
        
        folder_details[root] = {'subfolders': num_folders, 'images': num_images}
        total_folders += num_folders
        total_images += num_images
    
    return total_folders, total_images, folder_details

# Example usage
directory = r"E:\MAJOR PROJECT\Dataset\Massey"  # Change this to your target folder
folders, images, details = count_folders_images(directory)
print(f"Total Folders: {folders}")
print(f"Total Images: {images}")
print("Details:")
for folder, info in details.items():
    print(f"{folder}: {info}")
# Out:
# Total Folders: 36
# Total Images: 2520
# Details:
# E:\MAJOR PROJECT\Dataset\Massey: {'subfolders': 36, 'images': 0}
# E:\MAJOR PROJECT\Dataset\Massey\0: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\1: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\2: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\3: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\4: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\5: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\6: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\7: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\8: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\9: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\a: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\b: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\c: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\d: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\e: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\f: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\g: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\h: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\i: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\j: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\k: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\l: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\m: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\n: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\o: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\p: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\q: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\r: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\s: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\t: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\u: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\v: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\w: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\x: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\y: {'subfolders': 0, 'images': 70}
# E:\MAJOR PROJECT\Dataset\Massey\z: {'subfolders': 0, 'images': 70}
